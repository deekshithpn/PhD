# %%
import numpy as np
import pandas as pd

path = "/Users/Jayee/Library/CloudStorage/OneDrive-UW-Madison/PhD(Data)/Nanoindentation data-selected/Spherical Indentation data/Sph Indentation properties vs block parameters.xlsx"
required_columns = [0,1,2,3,4]
required_rows = [i for i in np.arange(18)]
df = pd.read_excel(path,sheet_name = 0, usecols=required_columns, nrows=19)

# %%
df
# Out:
#     Test Linear strain hardening co-efficient (GPa)  Yind (GPa)
# 0    NaN       Properties measured from indentation         NaN  \
# 1   2_56                                      12.23         2.4
# 2   2_46                                      11.07         3.2
# 3   2_64                                       2.68         3.7
# 4   2_10                                      16.79         3.2
# 5   2_29                                      11.21         3.4
# 6   2_34                                      12.32         2.2
# 7   2_75                                       16.1         3.0
# 8    2_4                                      26.26         1.6
# 9   1_48                                      14.83         3.0
# 10  2_18                                      11.47         3.5
# 11  2_16                                      27.38         2.6
# 12  2_70                                      10.45         3.8
# 13  2_90                                      21.72         3.2
# 14  2_40                                       3.53         3.6
# 15  2_50                                       8.86         3.4
# 16  2_30                                       22.8         3.3
# 17  2_77                                      16.78         3.0
#
#                     Distance (um)  Misorienatation (degrees)
# 0   Properties measured from EBSD                        NaN
# 1                            0.32                      11.79
# 2                            0.29                      46.36
# 3                             0.2                      58.93
# 4                             0.1                      53.32
# 5                            0.16                      51.81
# 6                            0.18                      56.69
# 7                            0.11                      44.88
# 8                            0.24                      21.34
# 9                            0.26                      13.74
# 10                           0.18                      57.06
# 11                           0.14                      27.40
# 12                           0.29                      50.86
# 13                           0.12                      56.25
# 14                           0.15                      52.36
# 15                           0.13                      57.53
# 16                           0.07                      56.85
# 17                           0.16                      58.98

# %%
df.to_excel("sp_indentation_data.xlsx",index="False)
