# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

matrix= scipy.io.loadmat("/home/ponnana/PhD/Yinling_copy/data_new.mat")

m = matrix["data_new"][:,0]
v =  matrix["data_new"][:,1]
s = matrix["data_new"][:,2]
k = matrix["data_new"][:,3]

tExp = [0.01058, 0.03158, 0.05258, 0.07358, 0.09458, 0.1156, 0.1366, 0.1576, 0.1786, 0.1996, 0.2206,
          0.2300, 0.2756, 0.3316, 0.3876, 0.4436, 0.4496, 0.5556, 0.6116, 0.6676, 0.7206, 0.7796, 0.8356,
          0.8916, 0.9476, 1.004, 1.060, 1.105, 1.124, 1.153, 1.182, 1.211, 1.240, 1.269, 1.298, 1.327,
          1.356, 1.385, 1.414, 1.443, 1.472, 1.501, 1.530, 1.559, 1.588, 1.617, 1.646, 1.670]

tExp = np.array(tExp)


t1,t2 = 0.24,1.1
xExp = np.concatenate((matrix["data_new"], tExp.reshape(-1,1)), axis=1)
# xExp = xExp.astype(double)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(12, 10), sharex=True)

# Plot Mean
axs[0, 0].plot(tExp, xExp[:, 0], 'r', label='Mean')
axs[0, 0].set_ylabel("Mean", fontsize=12)
axs[0, 0].legend()
axs[0, 0].set_facecolor('#F4F4F4')
axs[0, 0].grid(True, linestyle='--', alpha=0.6)

# Plot Variance
axs[0, 1].plot(tExp, xExp[:, 1], 'b', label='Variance')
axs[0, 1].set_ylabel("Variance", fontsize=12)
axs[0, 1].legend()
axs[0, 1].set_facecolor('#F4F4F4')
axs[0, 1].grid(True, linestyle='--', alpha=0.6)

# Plot Skewness
axs[1, 0].plot(tExp, xExp[:, 2], 'g', label='Skewness')
axs[1, 0].set_xlabel("Time", fontsize=12)
axs[1, 0].set_ylabel("Skewness", fontsize=12)
axs[1, 0].legend()
axs[1, 0].set_facecolor('#F4F4F4')
axs[1, 0].grid(True, linestyle='--', alpha=0.6)

# Plot Kurtosis
axs[1, 1].plot(tExp, xExp[:, 3], 'k', label='Kurtosis')
axs[1, 1].set_xlabel("Time", fontsize=12)
axs[1, 1].set_ylabel("Kurtosis", fontsize=12)
axs[1, 1].legend()
axs[1, 1].set_facecolor('#F4F4F4')
axs[1, 1].grid(True, linestyle='--', alpha=0.6)

# Customize the overall appearance
fig.suptitle("Evolutions of Different Parameters", fontsize=18, fontweight='bold')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust the layout to prevent clipping

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(tExpTrunc,xExpTruncNormal[:,0], 'r*',label='mean')

plt.plot(tExpTrunc,xExpTruncNormal[:,1], 'b*',label='variance')

plt.plot(tExpTrunc,xExpTruncNormal[:,2], 'g*',label='skewness')

plt.plot(tExpTrunc,xExpTruncNormal[:,3], 'k*',label='Kurtosis')

ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

# Customize fonts and sizes
ax.set_title("Evolution of Mean, Var, Skw, Kurt", fontsize=18, fontweight='bold')
ax.set_xlabel("Time", fontsize=14, fontweight='bold')
ax.set_ylabel("Y-axis", fontsize=14, fontweight='bold')

# Increase tick label font size
ax.tick_params(axis='both', labelsize=12)

# Customize the appearance of the legend
legend = ax.legend(loc='lower right', fontsize=12)
legend.get_frame().set_edgecolor('black')
ax.set_facecolor('#F4F4F4')

# Show the plot
plt.show()

# %%
maxValues = np.max(xExp,axis=0)
maxValues[-1]=1
xExpNormal = xExp/maxValues
truncIndex = np.where(xExpNormal[:,1]>=0.0999)
xExpTruncNormal = xExpNormal[truncIndex,:]
xExpTruncNormal = np.squeeze(xExpTruncNormal)

tExpTrunc = xExpTruncNormal[:,-1]

# %%
import os
import argparse
import time
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

torch.manual_seed(1000)
np.random.seed(1000)

parser = argparse.ArgumentParser('ODE demo')
parser.add_argument('--method', type=str, choices=['dopri5', 'adams'], default='dopri5')
parser.add_argument('--data_size', type=int, default=1000)
parser.add_argument('--batch_time', type=int, default=15)
parser.add_argument('--batch_size', type=int, default=100)
parser.add_argument('--niters', type=int, default=2000)
parser.add_argument('--test_freq', type=int, default=20)
parser.add_argument('--viz', action='store_true')
parser.add_argument('--gpu', type=int, default=0)
parser.add_argument('--adjoint', action='store_true')

# Parse arguments when running in Jupyter notebook
args = parser.parse_args(args=[])

if args.adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

# %%
from scipy.interpolate import interp1d
tTrain = np.linspace(np.min(tExpTrunc), np.max(tExpTrunc), args.data_size)
quad_interp = interp1d(tExpTrunc, xExpTruncNormal, kind='quadratic', axis=0)
xTrain = quad_interp(tTrain)

# %%
dmeanBydtTemp = xTrain[1:,0]-xTrain[0:-1,0]
dvarBydtTemp = xTrain[1:,1]-xTrain[0:-1,1]
dskwBydtTemp = xTrain[1:,2]-xTrain[0:-1,2]
dkurtBydtTemp = xTrain[1:,3]-xTrain[0:-1,3]
timeStep= tTrain[1]-tTrain[0]

dmeanBydtTemp = dmeanBydtTemp/timeStep
dvarBydtTemp = dvarBydtTemp/timeStep
dskwBydtTemp = dskwBydtTemp/timeStep
dkurtBydtTemp = dkurtBydtTemp/timeStep

dmeanBydt = np.append(dmeanBydtTemp,dmeanBydtTemp[-1])
dvarBydt = np.append(dvarBydtTemp,dvarBydtTemp[-1])
dskwBydt = np.append(dskwBydtTemp,dskwBydtTemp[-1])
dkurtBydt = np.append(dkurtBydtTemp,dkurtBydtTemp[-1])

dm_dt_fun = interp1d(tTrain, dmeanBydt, axis=0, fill_value='extrapolate')
dv_dt_fun = interp1d(tTrain, dvarBydt, axis=0, fill_value='extrapolate')
ds_dt_fun = interp1d(tTrain, dskwBydt, axis=0, fill_value='extrapolate')
dk_dt_fun = interp1d(tTrain, dkurtBydt, axis=0, fill_value='extrapolate')

# %%
clear true_y

# %%
## Setting up the true system
true_y0 = torch.from_numpy(xTrain[0,:]).to(device).to(dtype=torch.float)
t = torch.from_numpy(tTrain).to(dtype=torch.float)
true_y = torch.from_numpy(xTrain).unsqueeze(1).to(dtype=torch.float)

# %%
s = torch.from_numpy(np.random.choice(np.arange(args.data_size - args.batch_time, dtype=np.int64), args.batch_size, replace=False))
batch_y0 = true_y[s]  # (M, D)
batch_t = torch.stack([t[i:i+args.batch_time] for i in s]) # (T)
batch_y = torch.stack([true_y[s + i] for i in range(args.batch_time)], dim=1)  # (T, M, D)
batch_y=batch_y.permute(2,0,1,3)

# %%
## Get mini-batch data from the training dataset 
def get_batch():
    s = torch.from_numpy(np.random.choice(np.arange(args.data_size - args.batch_time, dtype=np.int64), args.batch_size, replace=False))
    batch_y0 = true_y[s]  # (M, D)
    batch_t = torch.stack([t[i:i+args.batch_time] for i in s]) # (T)
    batch_y = torch.stack([true_y[s + i] for i in range(args.batch_time)], dim=1)  # (T, M, D)
    batch_y=batch_y.permute(2,0,1,3)
    return batch_y0.to(device), batch_t.to(device), batch_y.to(device)

# %%
## Construct a neural network to approximate the dynamics of an ODE
class ODEFuncMean(nn.Module):

    def __init__(self):
        super(ODEFuncMean, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(5, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, 1)
        ).to(torch.float64)

        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)

    def forward(self, t, y):
        return self.net(y)
    
funcMean = ODEFuncMean().to(device)

# ## Construct a neural network to approximate the dynamics of an ODE
# class ODEFuncVariance(nn.Module):

#     def __init__(self):
#         super(ODEFuncVariance, self).__init__()

#         self.net = nn.Sequential(
#             nn.Linear(5, 64),
#             nn.Tanh(),
#             nn.Linear(64, 64),
#             nn.Tanh(),
#             nn.Linear(64, 1)
#         )

#         for m in self.net.modules():
#             if isinstance(m, nn.Linear):
#                 nn.init.normal_(m.weight, mean=0, std=0.1)
#                 nn.init.constant_(m.bias, val=0)

#     def forward(self, t, y):
#         return self.net(y)
    
# funcVariance = ODEFuncVariance().to(device)

# ## Construct a neural network to approximate the dynamics of an ODE
# class ODEFuncSkewness(nn.Module):

#     def __init__(self):
#         super(ODEFuncSkewness, self).__init__()

#         self.net = nn.Sequential(
#             nn.Linear(5, 64),
#             nn.Tanh(),
#             nn.Linear(64, 64),
#             nn.Tanh(),
#             nn.Linear(64, 1)
#         )

#         for m in self.net.modules():
#             if isinstance(m, nn.Linear):
#                 nn.init.normal_(m.weight, mean=0, std=0.1)
#                 nn.init.constant_(m.bias, val=0)

#     def forward(self, t, y):
#         return self.net(y)
    
# funcSkewness = ODEFuncSkewness().to(device)

# ## Construct a neural network to approximate the dynamics of an ODE
# class ODEFuncKurtosis(nn.Module):

#     def __init__(self):
#         super(ODEFuncKurtosis, self).__init__()

#         self.net = nn.Sequential(
#             nn.Linear(5, 64),
#             nn.Tanh(),
#             nn.Linear(64, 64),
#             nn.Tanh(),
#             nn.Linear(64, 1)
#         )

#         for m in self.net.modules():
#             if isinstance(m, nn.Linear):
#                 nn.init.normal_(m.weight, mean=0, std=0.1)
#                 nn.init.constant_(m.bias, val=0)

#     def forward(self, t, y):
#         return self.net(y)
    
# funcKurtosis = ODEFuncKurtosis().to(device)
    
def combined_system(tVar, y):
    # global t
    # global dmeanBydt
    # print(tVar.item())
    # dt_dt = 1.0
    # dt_dt = torch.tensor([dt_dt])
    # dm_dt = 1.0
    # dm_dt = torch.tensor([dm_dt])
    # dk_dt = dm_dt
    # dv_dt = dm_dt
    # ds_dt = dm_dt
    

    #indexTemp = np.where(t== tVar)[0].item()
    
    # dt_dt = 1.0
    # dt_dt = torch.tensor([dt_dt])
    
    # dm_dt = funcMean(tVar, y)
    
    # dv_dt = dvarBydt[indexTemp];
    # dv_dt = torch.tensor([dv_dt]).to(dtype=torch.double)

    # ds_dt = dskwBydt[indexTemp];
    # ds_dt = torch.tensor([ds_dt]).to(dtype=torch.double)

    # dk_dt = dkurtBydt[indexTemp];
    # dk_dt = torch.tensor([dk_dt]).to(dtype=torch.double)
    
    dt_dt = 1.0
    dt_dt = torch.tensor([dt_dt])
    
    dm_dt = funcMean(tVar, y)
    
    dv_dt = dv_dt_fun(tVar.item()).item()
    dv_dt = torch.tensor([dv_dt]).to(dtype=torch.double)
    
    ds_dt = ds_dt_fun(tVar.item()).item()
    ds_dt = torch.tensor([ds_dt]).to(dtype=torch.double)
    
    dk_dt = dk_dt_fun(tVar.item()).item()
    dk_dt = torch.tensor([dk_dt]).to(dtype=torch.double)
    
    return torch.cat([dm_dt, dv_dt, ds_dt, dk_dt, dt_dt], dim=0)

# %%
# Mean
parvalue = 0;

# %%
ii = 0
## Setting up the optimizer

# Setting up the optimizer with all parameters
optimizer = optim.RMSprop(funcMean.parameters(), lr=0.005)

for itr in range(1, args.niters + 1):
#for itr in range(1, 20):
        ## Using mini-batch data to update the neural network coefficients
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch()
        solutions = []
        temp1 = 0
        for ic in batch_y0:
            sol = odeint(combined_system, ic[0], batch_t[temp1])
            solutions.append(sol)
            temp1 = temp1+1
        pred_toCalcLoss= torch.stack(solutions)[:,:,0].unsqueeze(0)
        actual_toCalcLoss = batch_y[:,:,:,0]
        #pred_y = pred_y.permute(2, 1, 0, 3)
        loss = torch.mean(torch.abs(pred_toCalcLoss - actual_toCalcLoss))
        loss.backward()
        optimizer.step()

        if itr % args.test_freq == 0 or itr == 1:
            with torch.no_grad():
                pred_y = odeint(combined_system, true_y0, t)
                pred_toDisplay = pred_y[:,0].unsqueeze(1)
                actual_toDisplay = true_y[:,:,0]
                loss = torch.mean(torch.abs(pred_toDisplay - actual_toDisplay))
                print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))
                ii += 1
# Out:
# Iter 0001 | Total Loss 1.615434
# Iter 0020 | Total Loss 0.290008
# Iter 0040 | Total Loss 0.935887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[214], line 15
#      13 temp1 = 0
#      14 for ic in batch_y0:
# ---> 15     sol = odeint(combined_system, ic[0], batch_t[temp1])
#      16     solutions.append(sol)
#      17     temp1 = temp1+1
#
# File ~/.local/lib/python3.10/site-packages/torchdiffeq/_impl/odeint.py:77, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      74 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      76 if event_fn is None:
# ---> 77     solution = solver.integrate(t)
#      78 else:
#      79     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File ~/.local/lib/python3.10/site-packages/torchdiffeq/_impl/solvers.py:30, in AdaptiveStepsizeODESolver.integrate(self, t)
#      28 self._before_integrate(t)
#      29 for i in range(1, len(t)):
# ---> 30     solution[i] = self._advance(t[i])
#      31 return solution
#
# File ~/.local/lib/python3.10/site-packages/torchdiffeq/_impl/rk_common.py:194, in RKAdaptiveStepsizeODESolver._advance(self, next_t)
#     192 while next_t > self.rk_state.t1:
#     193     assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194     self.rk_state = self._adaptive_step(self.rk_state)
#     195     n_steps += 1
#     196 return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# File ~/.local/lib/python3.10/site-packages/torchdiffeq/_impl/rk_common.py:255, in RKAdaptiveStepsizeODESolver._adaptive_step(self, rk_state)
#     250         dt = t1 - t0
#     252 # Must be arranged as doing all the step_t handling, then all the jump_t handling, in case we
#     253 # trigger both. (i.e. interleaving them would be wrong.)
# --> 255 y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     256 # dtypes:
#     257 # y1.dtype == self.y0.dtype
#     258 # f1.dtype == self.y0.dtype
#    (...)
#     263 #                     Error Ratio                      #
#     264 ########################################################
#     265 error_ratio = _compute_error_ratio(y1_error, self.rtol, self.atol, y0, y1, self.norm)
#
# File ~/.local/lib/python3.10/site-packages/torchdiffeq/_impl/rk_common.py:75, in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      73     ti = t0 + alpha_i * dt
#      74     perturb = Perturb.NONE
# ---> 75 yi = y0 + torch.sum(k[..., :i + 1] * (beta_i * dt), dim=-1).view_as(f0)
#      76 f = func(ti, yi, perturb=perturb)
#      77 k = _UncheckedAssign.apply(k, f, (..., i + 1))
#
# KeyboardInterrupt:

# %%
# Setting up the optimizer with all parameters
optimizer = optim.RMSprop(all_parameters, lr=0.000005)

for itr in range(1, 10000):
#for itr in range(1, 20):
        ## Using mini-batch data to update the neural network coefficients
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch()
        solutions = []
        temp1 = 0
        for ic in batch_y0:
            sol = odeint(combined_system, ic[0], batch_t[temp1])
            solutions.append(sol)
            temp1 = temp1+1
        pred_y_toCaclLoss= torch.stack(solutions).unsqueeze(0)
        #pred_y = pred_y.permute(2, 1, 0, 3)
        loss = torch.mean(torch.abs(pred_y_toCaclLoss - batch_y))
        loss.backward()
        optimizer.step()

        if itr % args.test_freq == 0 or itr == 1:
            with torch.no_grad():
                pred_y = odeint(combined_system, true_y0, t)
                pred_y = pred_y.unsqueeze(1)  
                loss = torch.mean(torch.abs(pred_y - true_y))
                print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))
                ii += 1
# Out:
# Iter 0001 | Total Loss 0.239540
# Iter 0020 | Total Loss 0.240176

# %%
# Assuming ODEFunc is the name of your neural network class
modelMean = funcMean
# modelVar = funcVariance
# modelSkw = funcSkewness
# modelKurt = funcKurtosis


modelMean.eval()
# modelVar.eval()
# modelSkw.eval()
# modelKurt.eval()


# Initial state
y0 = true_y0
#y0= torch.tensor([ 0,  0.5, 0, 0])

# Time point for prediction
t_value = t
with torch.no_grad():
    predicted_states = odeint(combined_system,y0 , t).to(device)
    
predicted_states=predicted_states.numpy()

plot_kws = dict(linewidth=2)

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection="3d")

#ax.plot(x_train[:, 1], x_train[:, 2], x_train[:, 3], "k*", label="$given$")

ax.plot(predicted_states[:, 0], predicted_states[:, 1], predicted_states[:, 2], "r", label="$Neural-ODE-model$", linewidth=2.5,alpha =1)
ax.plot(temp_x_t_m_p2[:, 0], temp_x_t_m_p2[:, 1], temp_x_t_m_p2[:, 2], "b", label="True value", linewidth=2.5,alpha =0.6)
ax.set(xlabel="$Var$", ylabel="$Skw$", zlabel="$Kur$")
ax.legend()
fig.show()

#z_true = true_y[:,0,2].numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[216], line 33
#      30 #ax.plot(x_train[:, 1], x_train[:, 2], x_train[:, 3], "k*", label="$given$")
#      32 ax.plot(predicted_states[:, 0], predicted_states[:, 1], predicted_states[:, 2], "r", label="$Neural-ODE-model$", linewidth=2.5,alpha =1)
# ---> 33 ax.plot(temp_x_t_m_p2[:, 0], temp_x_t_m_p2[:, 1], temp_x_t_m_p2[:, 2], "b", label="True value", linewidth=2.5,alpha =0.6)
#      34 ax.set(xlabel="$Var$", ylabel="$Skw$", zlabel="$Kur$")
#      35 ax.legend()
#
# NameError: name 'temp_x_t_m_p2' is not defined

# %%
# Setting up the optimizer with all parameters
optimizer = optim.RMSprop(all_parameters, lr=0.00001)

for itr in range(2480, 10000):
#for itr in range(1, 20):
        ## Using mini-batch data to update the neural network coefficients
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch()
        solutions = []
        temp1 = 0
        for ic in batch_y0:
            sol = odeint(combined_system, ic[0], batch_t[temp1])
            solutions.append(sol)
            temp1 = temp1+1
        pred_y_toCaclLoss= torch.stack(solutions).unsqueeze(0)
        #pred_y = pred_y.permute(2, 1, 0, 3)
        loss = torch.mean(torch.abs(pred_y_toCaclLoss - batch_y))
        loss.backward()
        optimizer.step()

        if itr % args.test_freq == 0 or itr == 1:
            with torch.no_grad():
                pred_y = odeint(combined_system, true_y0, t)
                pred_y = pred_y.unsqueeze(1)  
                loss = torch.mean(torch.abs(pred_y - true_y))
                print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))
                ii += 1
# Out:
# Iter 2480 | Total Loss 0.155466
# Iter 2500 | Total Loss 0.152340
# Iter 2520 | Total Loss 0.156118
# Iter 2540 | Total Loss 0.155207
# Iter 2560 | Total Loss 0.156247
# Iter 2580 | Total Loss 0.158073
# Iter 2600 | Total Loss 0.155651
# Iter 2620 | Total Loss 0.155693
# Iter 2640 | Total Loss 0.155021
# Iter 2660 | Total Loss 0.156813
# Iter 2680 | Total Loss 0.159243
# Iter 2700 | Total Loss 0.159526
# Iter 2720 | Total Loss 0.157380
# Iter 2740 | Total Loss 0.157323
# Iter 2760 | Total Loss 0.156529
# Iter 2780 | Total Loss 0.157434
# Iter 2800 | Total Loss 0.158353
# Iter 2820 | Total Loss 0.159080
# Iter 2840 | Total Loss 0.159608
# Iter 2860 | Total Loss 0.159937
# Iter 2880 | Total Loss 0.161453
# Iter 2900 | Total Loss 0.158084
# Iter 2920 | Total Loss 0.158897
# Iter 2940 | Total Loss 0.158000
# Iter 2960 | Total Loss 0.160115
# Iter 2980 | Total Loss 0.159993
# Iter 3000 | Total Loss 0.160207
# Iter 3020 | Total Loss 0.159961
# Iter 3040 | Total Loss 0.158311
# Iter 3060 | Total Loss 0.158721
# Iter 3080 | Total Loss 0.160123
# Iter 3100 | Total Loss 0.159887
# Iter 3120 | Total Loss 0.159396
# Iter 3140 | Total Loss 0.162012
# Iter 3160 | Total Loss 0.161836
# Iter 3180 | Total Loss 0.159427
# Iter 3200 | Total Loss 0.159631
# Iter 3220 | Total Loss 0.159751
# Iter 3240 | Total Loss 0.160598
# Iter 3260 | Total Loss 0.158457
# Iter 3280 | Total Loss 0.161342
# Iter 3300 | Total Loss 0.160136
# Iter 3320 | Total Loss 0.158628
# Iter 3340 | Total Loss 0.159160
# Iter 3360 | Total Loss 0.161054
# Iter 3380 | Total Loss 0.157500
# Iter 3400 | Total Loss 0.158701
# Iter 3420 | Total Loss 0.158214
# Iter 3440 | Total Loss 0.159739
# Iter 3460 | Total Loss 0.158097
# Iter 3480 | Total Loss 0.156867
# Iter 3500 | Total Loss 0.156703
# Iter 3520 | Total Loss 0.157795
# Iter 3540 | Total Loss 0.158317
# Iter 3560 | Total Loss 0.158203
# Iter 3580 | Total Loss 0.158044
# Iter 3600 | Total Loss 0.155843
# Iter 3620 | Total Loss 0.156393
# Iter 3640 | Total Loss 0.154900
# Iter 3660 | Total Loss 0.156178
# Iter 3680 | Total Loss 0.154620
# Iter 3700 | Total Loss 0.155237
# Iter 3720 | Total Loss 0.154128
# Iter 3740 | Total Loss 0.152727
# Iter 3760 | Total Loss 0.156365
# Iter 3780 | Total Loss 0.154362
# Iter 3800 | Total Loss 0.153642
# Iter 3820 | Total Loss 0.153675
# Iter 3840 | Total Loss 0.153883
# Iter 3860 | Total Loss 0.154118
# Iter 3880 | Total Loss 0.154369
# Iter 3900 | Total Loss 0.156196
# Iter 3920 | Total Loss 0.155419
# Iter 3940 | Total Loss 0.153648
# Iter 3960 | Total Loss 0.154251
# Iter 3980 | Total Loss 0.155026
# Iter 4000 | Total Loss 0.155383
# Iter 4020 | Total Loss 0.155755
# Iter 4040 | Total Loss 0.155417
# Iter 4060 | Total Loss 0.155016
# Iter 4080 | Total Loss 0.154086
# Iter 4100 | Total Loss 0.154755
# Iter 4120 | Total Loss 0.156315
# Iter 4140 | Total Loss 0.157518
# Iter 4160 | Total Loss 0.157094
# Iter 4180 | Total Loss 0.156828
# Iter 4200 | Total Loss 0.156081
# Iter 4220 | Total Loss 0.154933
# Iter 4240 | Total Loss 0.154745
# Iter 4260 | Total Loss 0.153613
# Iter 4280 | Total Loss 0.154876
# Iter 4300 | Total Loss 0.154992
# Iter 4320 | Total Loss 0.152962
# Iter 4340 | Total Loss 0.155154
# Iter 4360 | Total Loss 0.153754
# Iter 4380 | Total Loss 0.155087
# Iter 4400 | Total Loss 0.155921
# Iter 4420 | Total Loss 0.156543
# Iter 4440 | Total Loss 0.155440
# Iter 4460 | Total Loss 0.156147
# Iter 4480 | Total Loss 0.154242
# Iter 4500 | Total Loss 0.157411
# Iter 4520 | Total Loss 0.155974
# Iter 4540 | Total Loss 0.155658
# Iter 4560 | Total Loss 0.156188
# Iter 4580 | Total Loss 0.158101
# Iter 4600 | Total Loss 0.155657
# Iter 4620 | Total Loss 0.157104
# Iter 4640 | Total Loss 0.153905
# Iter 4660 | Total Loss 0.154042
# Iter 4680 | Total Loss 0.154589
# Iter 4700 | Total Loss 0.151686
# Iter 4720 | Total Loss 0.152374
# Iter 4740 | Total Loss 0.153311
# Iter 4760 | Total Loss 0.151344
# Iter 4780 | Total Loss 0.152746
# Iter 4800 | Total Loss 0.152990
# Iter 4820 | Total Loss 0.153016
# Iter 4840 | Total Loss 0.151957
# Iter 4860 | Total Loss 0.150101
# Iter 4880 | Total Loss 0.150146
# Iter 4900 | Total Loss 0.151327
# Iter 4920 | Total Loss 0.152334
# Iter 4940 | Total Loss 0.152261
# Iter 4960 | Total Loss 0.153670
# Iter 4980 | Total Loss 0.152420
# Iter 5000 | Total Loss 0.152772
# Iter 5020 | Total Loss 0.153283
# Iter 5040 | Total Loss 0.153154
# Iter 5060 | Total Loss 0.151683
# Iter 5080 | Total Loss 0.151809
# Iter 5100 | Total Loss 0.152232
# Iter 5120 | Total Loss 0.151742
# Iter 5140 | Total Loss 0.149774
# Iter 5160 | Total Loss 0.149660
# Iter 5180 | Total Loss 0.151198
# Iter 5200 | Total Loss 0.150753
# Iter 5220 | Total Loss 0.150857
# Iter 5240 | Total Loss 0.149142
# Iter 5260 | Total Loss 0.150747
# Iter 5280 | Total Loss 0.150667
# Iter 5300 | Total Loss 0.151676
# Iter 5320 | Total Loss 0.150007
# Iter 5340 | Total Loss 0.150878
# Iter 5360 | Total Loss 0.151734
# Iter 5380 | Total Loss 0.152972
# Iter 5400 | Total Loss 0.152417
# Iter 5420 | Total Loss 0.153554
# Iter 5440 | Total Loss 0.152611
# Iter 5460 | Total Loss 0.150562
# Iter 5480 | Total Loss 0.149076
# Iter 5500 | Total Loss 0.149889
# Iter 5520 | Total Loss 0.150421
# Iter 5540 | Total Loss 0.148972
# Iter 5560 | Total Loss 0.149521
# Iter 5580 | Total Loss 0.151055
# Iter 5600 | Total Loss 0.149424
# Iter 5620 | Total Loss 0.151151
# Iter 5640 | Total Loss 0.151759
# Iter 5660 | Total Loss 0.150605
# Iter 5680 | Total Loss 0.150898
# Iter 5700 | Total Loss 0.149740
# Iter 5720 | Total Loss 0.150450
# Iter 5740 | Total Loss 0.149577
# Iter 5760 | Total Loss 0.149910
# Iter 5780 | Total Loss 0.151185
# Iter 5800 | Total Loss 0.150427
# Iter 5820 | Total Loss 0.149121
# Iter 5840 | Total Loss 0.148812
# Iter 5860 | Total Loss 0.149455
# Iter 5880 | Total Loss 0.148815
# Iter 5900 | Total Loss 0.149166
# Iter 5920 | Total Loss 0.150189
# Iter 5940 | Total Loss 0.148649
# Iter 5960 | Total Loss 0.147075
# Iter 5980 | Total Loss 0.147336
# Iter 6000 | Total Loss 0.147673
# Iter 6020 | Total Loss 0.147013
# Iter 6040 | Total Loss 0.146881
# Iter 6060 | Total Loss 0.148326
# Iter 6080 | Total Loss 0.148473
# Iter 6100 | Total Loss 0.148092
# Iter 6120 | Total Loss 0.148923
# Iter 6140 | Total Loss 0.148009
# Iter 6160 | Total Loss 0.148771
# Iter 6180 | Total Loss 0.150818
# Iter 6200 | Total Loss 0.149954
# Iter 6220 | Total Loss 0.147102
# Iter 6240 | Total Loss 0.146221
# Iter 6260 | Total Loss 0.147335
# Iter 6280 | Total Loss 0.145655
# Iter 6300 | Total Loss 0.147568
# Iter 6320 | Total Loss 0.147623
# Iter 6340 | Total Loss 0.146968
# Iter 6360 | Total Loss 0.146254
# Iter 6380 | Total Loss 0.145876
# Iter 6400 | Total Loss 0.146161
# Iter 6420 | Total Loss 0.146753
# Iter 6440 | Total Loss 0.145262
# Iter 6460 | Total Loss 0.143876
# Iter 6480 | Total Loss 0.143736
# Iter 6500 | Total Loss 0.145890
# Iter 6520 | Total Loss 0.147021
# Iter 6540 | Total Loss 0.148148
# Iter 6560 | Total Loss 0.145096
# Iter 6580 | Total Loss 0.146637
# Iter 6600 | Total Loss 0.146491
# Iter 6620 | Total Loss 0.146025
# Iter 6640 | Total Loss 0.145949
# Iter 6660 | Total Loss 0.147236
# Iter 6680 | Total Loss 0.147358
# Iter 6700 | Total Loss 0.144390
# Iter 6720 | Total Loss 0.145702
# Iter 6740 | Total Loss 0.145929
# Iter 6760 | Total Loss 0.144653
# Iter 6780 | Total Loss 0.145288
# Iter 6800 | Total Loss 0.145903
# Iter 6820 | Total Loss 0.146079
# Iter 6840 | Total Loss 0.145178
# Iter 6860 | Total Loss 0.146944
# Iter 6880 | Total Loss 0.145631
# Iter 6900 | Total Loss 0.145470
# Iter 6920 | Total Loss 0.146436
# Iter 6940 | Total Loss 0.144479
# Iter 6960 | Total Loss 0.145214
# Iter 6980 | Total Loss 0.144320
# Iter 7000 | Total Loss 0.146222
# Iter 7020 | Total Loss 0.146634
# Iter 7040 | Total Loss 0.146577
# Iter 7060 | Total Loss 0.148117
# Iter 7080 | Total Loss 0.147952
# Iter 7100 | Total Loss 0.147542
# Iter 7120 | Total Loss 0.145357
# Iter 7140 | Total Loss 0.143815
# Iter 7160 | Total Loss 0.143595
# Iter 7180 | Total Loss 0.143727
# Iter 7200 | Total Loss 0.143074
# Iter 7220 | Total Loss 0.143593
# Iter 7240 | Total Loss 0.145314
# Iter 7260 | Total Loss 0.145133
# Iter 7280 | Total Loss 0.142993
# Iter 7300 | Total Loss 0.142977
# Iter 7320 | Total Loss 0.143003
# Iter 7340 | Total Loss 0.142234
# Iter 7360 | Total Loss 0.143494
# Iter 7380 | Total Loss 0.143897
# Iter 7400 | Total Loss 0.144306
# Iter 7420 | Total Loss 0.146748
# Iter 7440 | Total Loss 0.145164
# Iter 7460 | Total Loss 0.143750
# Iter 7480 | Total Loss 0.145756
# Iter 7500 | Total Loss 0.142864
# Iter 7520 | Total Loss 0.144092
# Iter 7540 | Total Loss 0.145307
# Iter 7560 | Total Loss 0.145539
# Iter 7580 | Total Loss 0.143418
# Iter 7600 | Total Loss 0.143171
# Iter 7620 | Total Loss 0.144227
# Iter 7640 | Total Loss 0.142183
# Iter 7660 | Total Loss 0.142062
# Iter 7680 | Total Loss 0.143161
# Iter 7700 | Total Loss 0.141389
# Iter 7720 | Total Loss 0.143444
# Iter 7740 | Total Loss 0.141450
# Iter 7760 | Total Loss 0.142089
# Iter 7780 | Total Loss 0.141864
# Iter 7800 | Total Loss 0.139986
# Iter 7820 | Total Loss 0.141360
# Iter 7840 | Total Loss 0.139466
# Iter 7860 | Total Loss 0.141254
# Iter 7880 | Total Loss 0.140467
# Iter 7900 | Total Loss 0.141332
# Iter 7920 | Total Loss 0.142043
# Iter 7940 | Total Loss 0.142531
# Iter 7960 | Total Loss 0.140924
# Iter 7980 | Total Loss 0.141267
# Iter 8000 | Total Loss 0.141711
# Iter 8020 | Total Loss 0.144150
# Iter 8040 | Total Loss 0.142394
# Iter 8060 | Total Loss 0.142059
# Iter 8080 | Total Loss 0.142716
# Iter 8100 | Total Loss 0.141212
# Iter 8120 | Total Loss 0.142120
# Iter 8140 | Total Loss 0.142833
# Iter 8160 | Total Loss 0.143329
# Iter 8180 | Total Loss 0.142457
# Iter 8200 | Total Loss 0.141991
# Iter 8220 | Total Loss 0.142848
# Iter 8240 | Total Loss 0.140703
# Iter 8260 | Total Loss 0.139864
# Iter 8280 | Total Loss 0.142213
# Iter 8300 | Total Loss 0.141013
# Iter 8320 | Total Loss 0.140379
# Iter 8340 | Total Loss 0.141139
# Iter 8360 | Total Loss 0.140969
# Iter 8380 | Total Loss 0.142342
# Iter 8400 | Total Loss 0.140877
# Iter 8420 | Total Loss 0.141328
# Iter 8440 | Total Loss 0.142544
# Iter 8460 | Total Loss 0.142744
# Iter 8480 | Total Loss 0.141737
# Iter 8500 | Total Loss 0.141491
# Iter 8520 | Total Loss 0.141294
# Iter 8540 | Total Loss 0.140365
# Iter 8560 | Total Loss 0.140801
# Iter 8580 | Total Loss 0.139765
# Iter 8600 | Total Loss 0.141641
# Iter 8620 | Total Loss 0.141052
# Iter 8640 | Total Loss 0.141761
# Iter 8660 | Total Loss 0.141188
# Iter 8680 | Total Loss 0.140717
# Iter 8700 | Total Loss 0.140881
# Iter 8720 | Total Loss 0.143304
# Iter 8740 | Total Loss 0.140460
# Iter 8760 | Total Loss 0.141849
# Iter 8780 | Total Loss 0.139979
# Iter 8800 | Total Loss 0.143441
# Iter 8820 | Total Loss 0.142234
# Iter 8840 | Total Loss 0.140321
# Iter 8860 | Total Loss 0.139232
# Iter 8880 | Total Loss 0.141353
# Iter 8900 | Total Loss 0.137877
# Iter 8920 | Total Loss 0.139133
# Iter 8940 | Total Loss 0.138014
# Iter 8960 | Total Loss 0.139542
# Iter 8980 | Total Loss 0.140119
# Iter 9000 | Total Loss 0.138767
# Iter 9020 | Total Loss 0.139193
# Iter 9040 | Total Loss 0.139864
# Iter 9060 | Total Loss 0.139833
# Iter 9080 | Total Loss 0.141007
# Iter 9100 | Total Loss 0.139687
# Iter 9120 | Total Loss 0.138849
# Iter 9140 | Total Loss 0.140827
# Iter 9160 | Total Loss 0.140524
# Iter 9180 | Total Loss 0.139962
# Iter 9200 | Total Loss 0.139677
# Iter 9220 | Total Loss 0.140150
# Iter 9240 | Total Loss 0.139135
# Iter 9260 | Total Loss 0.138660
# Iter 9280 | Total Loss 0.139428
# Iter 9300 | Total Loss 0.139643
# Iter 9320 | Total Loss 0.138409
# Iter 9340 | Total Loss 0.137823
# Iter 9360 | Total Loss 0.138029
# Iter 9380 | Total Loss 0.138151
# Iter 9400 | Total Loss 0.139610
# Iter 9420 | Total Loss 0.141082
# Iter 9440 | Total Loss 0.140863
# Iter 9460 | Total Loss 0.139729
# Iter 9480 | Total Loss 0.141456
# Iter 9500 | Total Loss 0.140289
# Iter 9520 | Total Loss 0.141097
# Iter 9540 | Total Loss 0.141031
# Iter 9560 | Total Loss 0.140717
# Iter 9580 | Total Loss 0.140269
# Iter 9600 | Total Loss 0.142668
# Iter 9620 | Total Loss 0.143713
# Iter 9640 | Total Loss 0.141581
# Iter 9660 | Total Loss 0.142216
# Iter 9680 | Total Loss 0.142682
# Iter 9700 | Total Loss 0.141867
# Iter 9720 | Total Loss 0.143139
# Iter 9740 | Total Loss 0.142180
# Iter 9760 | Total Loss 0.143190
# Iter 9780 | Total Loss 0.142221
# Iter 9800 | Total Loss 0.141835
# Iter 9820 | Total Loss 0.143301
# Iter 9840 | Total Loss 0.142047
# Iter 9860 | Total Loss 0.141921
# Iter 9880 | Total Loss 0.143654
# Iter 9900 | Total Loss 0.141759
# Iter 9920 | Total Loss 0.145402
# Iter 9940 | Total Loss 0.143175
# Iter 9960 | Total Loss 0.143274
# Iter 9980 | Total Loss 0.144649

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(tTrain,xTrain[:,0], 'r',label='mean exp')
plt.plot(tTrain,predicted_states[:,0], 'r--',label='mean NODE')

plt.plot(tTrain,xTrain[:,1], 'b',label='variance exp')
plt.plot(tTrain,predicted_states[:,1], 'b--',label='variance NODE')

plt.plot(tTrain,xTrain[:,2], 'g',label='skewness exp')
plt.plot(tTrain,predicted_states[:,2], 'g--',label='skewness NODE')

plt.plot(tTrain,xTrain[:,3], 'k',label='Kurtosis exp')
plt.plot(tTrain,predicted_states[:,3], 'k--',label='Kurtosis NODE')

ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

# Customize fonts and sizes
ax.set_title("Learning evolution of Mean, Var, Skw, Kurt in Part1", fontsize=18, fontweight='bold')
ax.set_xlabel("X-axis", fontsize=14, fontweight='bold')
ax.set_ylabel("Y-axis", fontsize=14, fontweight='bold')

# Increase tick label font size
ax.tick_params(axis='both', labelsize=12)

# Customize the appearance of the legend
legend = ax.legend(loc='lower right', fontsize=12)
legend.get_frame().set_edgecolor('black')
ax.set_facecolor('#F4F4F4')

plt.savefig('individualNN_64_64_1.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
torch.save(funcMean, 'mean64_64.pth')
torch.save(funcVariance, 'variance64_64.pth')
torch.save(funcSkewness, 'skewness64_64.pth')
torch.save(funcKurtosis, 'kurtosis64_64.pth')

# %%
# Create a plot with different labels for each column
plt.plot(temp_m_t_p1, temp_x_t_m_p1[:, 1], 'r*',label='Variance')
plt.plot(temp_m_t_p1, temp_x_t_m_p1[:, 2], 'b*',label='skewness')
plt.plot(temp_m_t_p1, temp_x_t_m_p1[:, 3], 'g*',label='Kurtosis')

plt.plot(t, predicted_states[:, 1], 'r',label='Variance')
plt.plot(t, predicted_states[:, 2], 'b',label='skewness')
plt.plot(t, predicted_states[:, 3], 'g',label='Kurtosis')

# Add labels and title
plt.xlabel('Mean')
plt.ylabel('Y-axis')
plt.title('Var, Skw, Kur with mean')

# Add a legend
plt.legend()

# Add grid
plt.grid(True, linestyle='--', alpha=0.6)

# Display the plot
plt.show()

# %%
plt.plot(x_t_m_p1[:,1])
plt.plot(predicted_states[:,1])

# %%
plt.plot(x_t_m_p1[:,2])
plt.plot(predicted_states[:,2])

# %%
plt.plot(x_t_m_p1[:,3])
plt.plot(predicted_states[:,3])

# %%
plt.plot(x_t_m_p1[:,2])
plt.plot(predicted_states[:,2])

# %%
plt.plot(x_t_m_p1[:,3])
plt.plot(predicted_states[:,3])
