# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

matrix= scipy.io.loadmat("/home/ponnana/PhD/Yinling_copy/data_new.mat")

m = matrix["data_new"][:,0]
v =  matrix["data_new"][:,1]
s = matrix["data_new"][:,2]
k = matrix["data_new"][:,3]

tExp = [0.01058, 0.03158, 0.05258, 0.07358, 0.09458, 0.1156, 0.1366, 0.1576, 0.1786, 0.1996, 0.2206,
          0.2300, 0.2756, 0.3316, 0.3876, 0.4436, 0.4496, 0.5556, 0.6116, 0.6676, 0.7206, 0.7796, 0.8356,
          0.8916, 0.9476, 1.004, 1.060, 1.105, 1.124, 1.153, 1.182, 1.211, 1.240, 1.269, 1.298, 1.327,
          1.356, 1.385, 1.414, 1.443, 1.472, 1.501, 1.530, 1.559, 1.588, 1.617, 1.646, 1.670]

tExp = np.array(tExp)


t1,t2 = 0.24,1.1
xExp = np.concatenate((matrix["data_new"], tExp.reshape(-1,1)), axis=1)
xExp = xExp.astype(float)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(12, 10), sharex=True)

# Plot Mean
axs[0, 0].plot(tExp, xExp[:, 0], 'r', label='Mean')
axs[0, 0].set_ylabel("Mean", fontsize=12)
axs[0, 0].legend()
axs[0, 0].set_facecolor('#F4F4F4')
axs[0, 0].grid(True, linestyle='--', alpha=0.6)

# Plot Variance
axs[0, 1].plot(tExp, xExp[:, 1], 'b', label='Variance')
axs[0, 1].set_ylabel("Variance", fontsize=12)
axs[0, 1].legend()
axs[0, 1].set_facecolor('#F4F4F4')
axs[0, 1].grid(True, linestyle='--', alpha=0.6)

# Plot Skewness
axs[1, 0].plot(tExp, xExp[:, 2], 'g', label='Skewness')
axs[1, 0].set_xlabel("Time", fontsize=12)
axs[1, 0].set_ylabel("Skewness", fontsize=12)
axs[1, 0].legend()
axs[1, 0].set_facecolor('#F4F4F4')
axs[1, 0].grid(True, linestyle='--', alpha=0.6)

# Plot Kurtosis
axs[1, 1].plot(tExp, xExp[:, 3], 'k', label='Kurtosis')
axs[1, 1].set_xlabel("Time", fontsize=12)
axs[1, 1].set_ylabel("Kurtosis", fontsize=12)
axs[1, 1].legend()
axs[1, 1].set_facecolor('#F4F4F4')
axs[1, 1].grid(True, linestyle='--', alpha=0.6)

# Customize the overall appearance
fig.suptitle("Evolutions of Different Parameters", fontsize=18, fontweight='bold')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust the layout to prevent clipping

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(12, 10), sharex=True)

# Plot Mean
axs[0, 0].plot(tExp, xExp[:, 0], 'r', label='Mean')
axs[0, 0].set_ylabel("Mean", fontsize=12)
axs[0, 0].legend()
axs[0, 0].set_facecolor('#F4F4F4')
axs[0, 0].grid(True, linestyle='--', alpha=0.6)

# Plot Variance
axs[0, 1].plot(tExp, xExp[:, 1], 'b', label='Variance')
axs[0, 1].set_ylabel("Variance", fontsize=12)
axs[0, 1].legend()
axs[0, 1].set_facecolor('#F4F4F4')
axs[0, 1].grid(True, linestyle='--', alpha=0.6)

# Plot Skewness
axs[1, 0].plot(tExp, xExp[:, 2], 'g', label='Skewness')
axs[1, 0].set_xlabel("Time", fontsize=12)
axs[1, 0].set_ylabel("Skewness", fontsize=12)
axs[1, 0].legend()
axs[1, 0].set_facecolor('#F4F4F4')
axs[1, 0].grid(True, linestyle='--', alpha=0.6)

# Plot Kurtosis
axs[1, 1].plot(tExp, xExp[:, 3], 'k', label='Kurtosis')
axs[1, 1].set_xlabel("Time", fontsize=12)
axs[1, 1].set_ylabel("Kurtosis", fontsize=12)
axs[1, 1].legend()
axs[1, 1].set_facecolor('#F4F4F4')
axs[1, 1].grid(True, linestyle='--', alpha=0.6)

# Customize the overall appearance
fig.suptitle("Evolutions of Different Parameters", fontsize=18, fontweight='bold')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust the layout to prevent clipping

# Show the plot
plt.show()

# %%
maxValues = np.max(xExp,axis=0)
maxValues[-1]=1
xExpNormal = xExp/maxValues
truncIndex = np.where(xExpNormal[:,1]>=0.0999)
xExpTruncNormal = xExpNormal[truncIndex,:]
xExpTruncNormal = np.squeeze(xExpTruncNormal)
tExpTrunc = xExpTruncNormal[:,-1]

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(tExpTrunc,xExpTruncNormal[:,0], 'r*',label='mean')

plt.plot(tExpTrunc,xExpTruncNormal[:,1], 'b*',label='variance')

plt.plot(tExpTrunc,xExpTruncNormal[:,2], 'g*',label='skewness')

plt.plot(tExpTrunc,xExpTruncNormal[:,3], 'k*',label='Kurtosis')

ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

# Customize fonts and sizes
ax.set_title("Evolution of Mean, Var, Skw, Kurt", fontsize=18, fontweight='bold')
ax.set_xlabel("Time", fontsize=14, fontweight='bold')
ax.set_ylabel("Y-axis", fontsize=14, fontweight='bold')

# Increase tick label font size
ax.tick_params(axis='both', labelsize=12)

# Customize the appearance of the legend
legend = ax.legend(loc='lower right', fontsize=12)
legend.get_frame().set_edgecolor('black')
ax.set_facecolor('#F4F4F4')

# Show the plot
plt.show()

# %%
tBreak1 = 0.23
tBreak2 = 1.105
xExpTruncNormal1 = xExpTruncNormal[0:np.where(tExpTrunc==tBreak1)[0][0]+1,:]
xExpTruncNormal2 = xExpTruncNormal[np.where(tExpTrunc==tBreak1)[0][0]+1:np.where(tExpTrunc==tBreak2)[0][0]+1,:]
xExpTruncNormal3 = xExpTruncNormal[np.where(tExpTrunc==tBreak2)[0][0]+1:,:]

tExpTrunc1= xExpTruncNormal1[:,-1]
tExpTrunc2= xExpTruncNormal2[:,-1]
tExpTrunc3= xExpTruncNormal3[:,-1]

# %%
import os
import argparse
import time
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

torch.manual_seed(1000)
np.random.seed(1000)

parser = argparse.ArgumentParser('ODE demo')
parser.add_argument('--method', type=str, choices=['dopri5', 'adams'], default='dopri5')
parser.add_argument('--data_size', type=int, default=1000)
parser.add_argument('--batch_time', type=int, default=15)
parser.add_argument('--batch_size', type=int, default=30)
parser.add_argument('--niters', type=int, default=2000)
parser.add_argument('--test_freq', type=int, default=20)
parser.add_argument('--viz', action='store_true')
parser.add_argument('--gpu', type=int, default=0)
parser.add_argument('--adjoint', action='store_true')

# Parse arguments when running in Jupyter notebook
args = parser.parse_args(args=[])

if args.adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Part1 (0-0.24 sec)

# %%
from scipy.interpolate import interp1d
tTrain2 = np.linspace(np.min(tExpTrunc2), np.max(tExpTrunc2), args.data_size)
quad_interp_p2 = interp1d(tExpTrunc2, xExpTruncNormal2, kind='quadratic', axis=0)
xTrain2 = quad_interp_p2(tTrain2)

# %%
clear true_y

# %%
## Setting up the true system
true_y0 = torch.from_numpy(xTrain2[0,:]).to(device).to(dtype=torch.float)
t = torch.from_numpy(tTrain2).to(dtype=torch.float)
true_y = torch.from_numpy(xTrain2).unsqueeze(1).to(dtype=torch.float)

# %%
## Get mini-batch data from the training dataset 
def get_batch():
    s = torch.from_numpy(np.random.choice(np.arange(args.data_size - args.batch_time, dtype=np.int64), args.batch_size, replace=False))
    batch_y0 = true_y[s]  # (M, D)
    batch_t = torch.stack([t[i:i+args.batch_time] for i in s]) # (T)
    batch_y = torch.stack([true_y[s + i] for i in range(args.batch_time)], dim=1)  # (T, M, D)
    batch_y=batch_y.permute(2,0,1,3)
    return batch_y0.to(device), batch_t.to(device), batch_y.to(device)

## Utility functions for visualization of results 
def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)

if args.viz:
    makedirs('png')
    import matplotlib.pyplot as plt
    fig = plt.figure(figsize=(8, 4), facecolor='white')
    ax_traj = fig.add_subplot(121, frameon=False)
    ax_phase = fig.add_subplot(122, frameon=False)
    plt.show(block=False)

def visualize(true_y, pred_y, odefunc, itr):

    if args.viz:

        ax_traj.cla()
        ax_traj.set_title('Trajectories')
        ax_traj.set_xlabel('t')
        ax_traj.set_ylabel('x,y')
        ax_traj.plot(t.cpu().numpy(), true_y.cpu().numpy()[:, 0, 0], t.cpu().numpy(), true_y.cpu().numpy()[:, 0, 1], 'g-', label = 'True System')
        ax_traj.plot(t.cpu().numpy(), pred_y.cpu().numpy()[:, 0, 0], '--', t.cpu().numpy(), pred_y.cpu().numpy()[:, 0, 1], 'b--', label = 'Neural ODE')
        ax_traj.set_xlim(t.cpu().min(), t.cpu().max())
        ax_traj.set_ylim(-2, 2)
        ax_traj.legend()

        ax_phase.cla()
        ax_phase.set_title('Phase Portrait')
        ax_phase.set_xlabel('x')
        ax_phase.set_ylabel('y')
        ax_phase.plot(true_y.cpu().numpy()[:, 0, 0], true_y.cpu().numpy()[:, 0, 1], 'g-')
        ax_phase.plot(pred_y.cpu().numpy()[:, 0, 0], pred_y.cpu().numpy()[:, 0, 1], 'b--')
        ax_phase.set_xlim(-2, 2)
        ax_phase.set_ylim(-2, 2)

        fig.tight_layout()
        plt.savefig('png/{:03d}'.format(itr))
        plt.draw()
        plt.pause(0.001)


## Construct a neural network to approximate the dynamics of an ODE
class ODEFunc(nn.Module):

    def __init__(self):
        super(ODEFunc, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(5, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, 4)
        )

        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)

    def forward(self, t, y):
        return self.net(y)
    
func = ODEFunc().to(device)
    
def combined_system(t, y):
    dt_dt = 1;
    dt_dt = torch.tensor([dt_dt])
    output_tensor = func(t, y)  # Using ODEFunc to get dx2/dt, dx3/dt, dx4/dt
    return torch.cat([output_tensor,dt_dt], dim=0)

# %%
ii = 0
## Setting up the optimizer
optimizer = optim.RMSprop(func.parameters(), lr=0.0001)

for itr in range(1, args.niters + 1):
#for itr in range(1, 20):
        ## Using mini-batch data to update the neural network coefficients
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch()
        solutions = []
        temp1 = 0
        for ic in batch_y0:
            sol = odeint(combined_system, ic[0], batch_t[temp1])
            solutions.append(sol)
            temp1 = temp1+1
        pred_y_toCaclLoss= torch.stack(solutions).unsqueeze(0)
        #pred_y = pred_y.permute(2, 1, 0, 3)
        loss = torch.mean(torch.abs(pred_y_toCaclLoss - batch_y))
        loss.backward()
        optimizer.step()

        if itr % args.test_freq == 0 or itr == 1:
            with torch.no_grad():
                pred_y = odeint(combined_system, true_y0, t)
                pred_y = pred_y.unsqueeze(1)  
                loss = torch.mean(torch.abs(pred_y - true_y))
                print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))
                visualize(true_y, pred_y, func, ii)
                ii += 1
# Out:
# Iter 0001 | Total Loss 0.102002
# Iter 0020 | Total Loss 0.051536
# Iter 0040 | Total Loss 0.040895
# Iter 0060 | Total Loss 0.038674
# Iter 0080 | Total Loss 0.038957
# Iter 0100 | Total Loss 0.036899
# Iter 0120 | Total Loss 0.036006
# Iter 0140 | Total Loss 0.033582
# Iter 0160 | Total Loss 0.033468
# Iter 0180 | Total Loss 0.031910
# Iter 0200 | Total Loss 0.030097
# Iter 0220 | Total Loss 0.031073
# Iter 0240 | Total Loss 0.031571
# Iter 0260 | Total Loss 0.029994
# Iter 0280 | Total Loss 0.029905
# Iter 0300 | Total Loss 0.028295
# Iter 0320 | Total Loss 0.029087
# Iter 0340 | Total Loss 0.028889
# Iter 0360 | Total Loss 0.028521
# Iter 0380 | Total Loss 0.027237
# Iter 0400 | Total Loss 0.027534
# Iter 0420 | Total Loss 0.027666
# Iter 0440 | Total Loss 0.027875
# Iter 0460 | Total Loss 0.027783
# Iter 0480 | Total Loss 0.026538
# Iter 0500 | Total Loss 0.028580
# Iter 0520 | Total Loss 0.027049
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 19
#      17 #pred_y = pred_y.permute(2, 1, 0, 3)
#      18 loss = torch.mean(torch.abs(pred_y_toCaclLoss - batch_y))
# ---> 19 loss.backward()
#      20 optimizer.step()
#      22 if itr % args.test_freq == 0 or itr == 1:
#
# File ~/.local/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/function.py:276, in BackwardCFunction.apply(self, *args)
#     275 class BackwardCFunction(_C._FunctionBase, FunctionCtx, _HookMixin):
# --> 276     def apply(self, *args):
#     277         # _forward_cls is defined by derived class
#     278         # The user should define either backward or vjp but never both.
#     279         backward_fn = self._forward_cls.backward  # type: ignore[attr-defined]
#     280         vjp_fn = self._forward_cls.vjp  # type: ignore[attr-defined]
#
# KeyboardInterrupt:

# %%
optimizer = optim.RMSprop(func.parameters(), lr=0.00001)

for itr in range(520, 3000):
#for itr in range(1, 20):
        ## Using mini-batch data to update the neural network coefficients
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch()
        solutions = []
        temp1 = 0
        for ic in batch_y0:
            sol = odeint(combined_system, ic[0], batch_t[temp1])
            solutions.append(sol)
            temp1 = temp1+1
        pred_y_toCaclLoss= torch.stack(solutions).unsqueeze(0)
        #pred_y = pred_y.permute(2, 1, 0, 3)
        loss = torch.mean(torch.abs(pred_y_toCaclLoss - batch_y))
        loss.backward()
        optimizer.step()

        if itr % args.test_freq == 0 or itr == 1:
            with torch.no_grad():
                pred_y = odeint(combined_system, true_y0, t)
                pred_y = pred_y.unsqueeze(1)  
                loss = torch.mean(torch.abs(pred_y - true_y))
                print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))
                visualize(true_y, pred_y, func, ii)
                ii += 1
# Out:
# Iter 0520 | Total Loss 0.027323
# Iter 0540 | Total Loss 0.026634
# Iter 0560 | Total Loss 0.026692
# Iter 0580 | Total Loss 0.027032
# Iter 0600 | Total Loss 0.026941
# Iter 0620 | Total Loss 0.027407
# Iter 0640 | Total Loss 0.026453
# Iter 0660 | Total Loss 0.026516
# Iter 0680 | Total Loss 0.026986
# Iter 0700 | Total Loss 0.026590
# Iter 0720 | Total Loss 0.026508
# Iter 0740 | Total Loss 0.026300
# Iter 0760 | Total Loss 0.026235
# Iter 0780 | Total Loss 0.026783
# Iter 0800 | Total Loss 0.026092
# Iter 0820 | Total Loss 0.026198
# Iter 0840 | Total Loss 0.026319
# Iter 0860 | Total Loss 0.026413
# Iter 0880 | Total Loss 0.026547
# Iter 0900 | Total Loss 0.026306
# Iter 0920 | Total Loss 0.026329
# Iter 0940 | Total Loss 0.026122
# Iter 0960 | Total Loss 0.026125
# Iter 0980 | Total Loss 0.026208
# Iter 1000 | Total Loss 0.025901
# Iter 1020 | Total Loss 0.026015
# Iter 1040 | Total Loss 0.025730
# Iter 1060 | Total Loss 0.025596
# Iter 1080 | Total Loss 0.025784
# Iter 1100 | Total Loss 0.025538
# Iter 1120 | Total Loss 0.025821
# Iter 1140 | Total Loss 0.025967
# Iter 1160 | Total Loss 0.025589
# Iter 1180 | Total Loss 0.025609
# Iter 1200 | Total Loss 0.025454
# Iter 1220 | Total Loss 0.025689
# Iter 1240 | Total Loss 0.025864
# Iter 1260 | Total Loss 0.025848
# Iter 1280 | Total Loss 0.025623
# Iter 1300 | Total Loss 0.026132
# Iter 1320 | Total Loss 0.025833
# Iter 1340 | Total Loss 0.026025
# Iter 1360 | Total Loss 0.025983
# Iter 1380 | Total Loss 0.025834
# Iter 1400 | Total Loss 0.025726
# Iter 1420 | Total Loss 0.026067
# Iter 1440 | Total Loss 0.025790
# Iter 1460 | Total Loss 0.025486
# Iter 1480 | Total Loss 0.025688
# Iter 1500 | Total Loss 0.025687
# Iter 1520 | Total Loss 0.025516
# Iter 1540 | Total Loss 0.025608
# Iter 1560 | Total Loss 0.025327
# Iter 1580 | Total Loss 0.025455
# Iter 1600 | Total Loss 0.025355
# Iter 1620 | Total Loss 0.025665
# Iter 1640 | Total Loss 0.025473
# Iter 1660 | Total Loss 0.025552
# Iter 1680 | Total Loss 0.025365
# Iter 1700 | Total Loss 0.025166
# Iter 1720 | Total Loss 0.025349
# Iter 1740 | Total Loss 0.025235
# Iter 1760 | Total Loss 0.025523
# Iter 1780 | Total Loss 0.025361
# Iter 1800 | Total Loss 0.025027
# Iter 1820 | Total Loss 0.025210
# Iter 1840 | Total Loss 0.025268
# Iter 1860 | Total Loss 0.025447
# Iter 1880 | Total Loss 0.025215
# Iter 1900 | Total Loss 0.025151
# Iter 1920 | Total Loss 0.025338
# Iter 1940 | Total Loss 0.025247
# Iter 1960 | Total Loss 0.025286
# Iter 1980 | Total Loss 0.024884
# Iter 2000 | Total Loss 0.024948
# Iter 2020 | Total Loss 0.025087
# Iter 2040 | Total Loss 0.025060
# Iter 2060 | Total Loss 0.025273
# Iter 2080 | Total Loss 0.025120
# Iter 2100 | Total Loss 0.025022
# Iter 2120 | Total Loss 0.025351
# Iter 2140 | Total Loss 0.025257
# Iter 2160 | Total Loss 0.025272
# Iter 2180 | Total Loss 0.024802
# Iter 2200 | Total Loss 0.025001
# Iter 2220 | Total Loss 0.024951
# Iter 2240 | Total Loss 0.024822
# Iter 2260 | Total Loss 0.025012
# Iter 2280 | Total Loss 0.024900
# Iter 2300 | Total Loss 0.024906
# Iter 2320 | Total Loss 0.024958
# Iter 2340 | Total Loss 0.025252
# Iter 2360 | Total Loss 0.025245
# Iter 2380 | Total Loss 0.024937
# Iter 2400 | Total Loss 0.024955
# Iter 2420 | Total Loss 0.024847
# Iter 2440 | Total Loss 0.024831
# Iter 2460 | Total Loss 0.024977
# Iter 2480 | Total Loss 0.025119
# Iter 2500 | Total Loss 0.024609
# Iter 2520 | Total Loss 0.024841
# Iter 2540 | Total Loss 0.025203
# Iter 2560 | Total Loss 0.025204
# Iter 2580 | Total Loss 0.025072
# Iter 2600 | Total Loss 0.024885
# Iter 2620 | Total Loss 0.024656
# Iter 2640 | Total Loss 0.024613
# Iter 2660 | Total Loss 0.024670
# Iter 2680 | Total Loss 0.024913
# Iter 2700 | Total Loss 0.024808
# Iter 2720 | Total Loss 0.024678
# Iter 2740 | Total Loss 0.024796
# Iter 2760 | Total Loss 0.024709
# Iter 2780 | Total Loss 0.024893
# Iter 2800 | Total Loss 0.024744
# Iter 2820 | Total Loss 0.024639
# Iter 2840 | Total Loss 0.024678
# Iter 2860 | Total Loss 0.024741
# Iter 2880 | Total Loss 0.024525
# Iter 2900 | Total Loss 0.024478
# Iter 2920 | Total Loss 0.024755
# Iter 2940 | Total Loss 0.024578
# Iter 2960 | Total Loss 0.024392
# Iter 2980 | Total Loss 0.024361

# %%
# Assuming ODEFunc is the name of your neural network class
model = func


model.eval()


# Initial state
y0 = true_y0
#y0= torch.tensor([ 0,  0.5, 0, 0])

# Time point for prediction
t_value = t
with torch.no_grad():
    predicted_states = odeint(combined_system,y0 , t).to(device)
    
predicted_states=predicted_states.numpy()

plot_kws = dict(linewidth=2)

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection="3d")

#ax.plot(x_train[:, 1], x_train[:, 2], x_train[:, 3], "k*", label="$given$")

ax.plot(predicted_states[:, 1], predicted_states[:, 2], predicted_states[:, 3], "r", label="$Neural$", linewidth=2.5,alpha =1)
ax.plot(xExpTruncNormal2[:, 1], xExpTruncNormal2[:, 2],xExpTruncNormal2[:, 3], "b--", label="$True$", linewidth=2.5,alpha =0.6)
ax.set(xlabel="$Var$", ylabel="$Skw$", zlabel="$Kur$")
ax.legend()
fig.show()

#z_true = true_y[:,0,2].numpy()
# Out:
# /tmp/ipykernel_838846/3859108107.py:30: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(tTrain2,xTrain2[:,0], 'r',label='mean exp')
plt.plot(tTrain2,predicted_states[:,0], 'r--',label='mean NODE')

plt.plot(tTrain2,xTrain2[:,1], 'b',label='variance exp')
plt.plot(tTrain2,predicted_states[:,1], 'b--',label='variance NODE')

plt.plot(tTrain2,xTrain2[:,2], 'g',label='skewness exp')
plt.plot(tTrain2,predicted_states[:,2], 'g--',label='skewness NODE')

plt.plot(tTrain2,xTrain2[:,3], 'k',label='Kurtosis exp')
plt.plot(tTrain2,predicted_states[:,3], 'k--',label='Kurtosis NODE')

ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

# Customize fonts and sizes
ax.set_title("Learning evolution of Mean, Var, Skw, Kurt in Part2", fontsize=18, fontweight='bold')
ax.set_xlabel("X-axis", fontsize=14, fontweight='bold')
ax.set_ylabel("Y-axis", fontsize=14, fontweight='bold')

# Increase tick label font size
ax.tick_params(axis='both', labelsize=12)

# Customize the appearance of the legend
legend = ax.legend(loc='lower right', fontsize=12)
legend.get_frame().set_edgecolor('black')
ax.set_facecolor('#F4F4F4')

plt.savefig('learningPart2.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
torch.save(func, 'part2.pth')

# %%
# Out:
# /home/ponnana
