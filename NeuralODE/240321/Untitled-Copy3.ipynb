# %% [markdown]
# ## System 1: Homoclinic orbits
#
# dx/dt = y
#
# dy/dt = x-x^3

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# %%
def func1(t,state):
    x, y = state
    dx_dt = y
    dy_dt = x-x**3
    velocity = np.array([dx_dt, dy_dt])
    return velocity

state_0 = np.array([1,1])
func1(1,state_0)

solution=solve_ivp(func1, (0,20), state_0, dense_output = True)

# %%
# Plot
fro, to = 0,10
tTrain = np.linspace(fro, to, 10000)
xTraindummy = solution.sol(tTrain)
xTrain = np.transpose(xTraindummy)

fig,axs = plt.subplots(figsize=(10,8))
axs.plot(xTrain[:,0],xTrain[:,1], "b-", linewidth=3, label ="Phase Trajectory")

axs.set_title("Phase Portrait of function 1", fontweight = "bold", fontsize=20)
axs.set_xlabel("x-Axis", fontweight= "bold", fontsize=20)
axs.set_ylabel("yaxis", fontweight="bold", fontsize=20)

axs.tick_params(direction="in", length =10, width=2, labelsize=15)

for spine in axs.spines.values():
    spine.set_linewidth(2)
    
legend = axs.legend(fontsize=15)
legend.get_frame().set_edgecolor("black")
legend.get_frame().set_linewidth(2)
legend.get_frame().set_facecolor("pink")
axs.set_facecolor("#f4f4f4")
axs.grid(True, linestyle = "--", linewidth=2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

import os
import argparse
import time

import torch
import torch.nn as nn
import torch.optim as optim

torch.manual_seed(1000)
np.random.seed(1000)

parser = argparse.ArgumentParser('ODE demo')
parser.add_argument('--method', type=str, choices=['dopri5', 'adams'], default='dopri5')
parser.add_argument('--data_size', type=int, default=1000)
parser.add_argument('--batch_time', type=int, default=15)
parser.add_argument('--batch_size', type=int, default=15)
parser.add_argument('--niters', type=int, default=2000)
parser.add_argument('--test_freq', type=int, default=20)
parser.add_argument('--viz', action='store_true')
parser.add_argument('--gpu', type=int, default=0)
parser.add_argument('--adjoint', action='store_true')

# Parse arguments when running in Jupyter notebook
args = parser.parse_args(args=[])

if args.adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

# %%
xTrain
# Out:
# array([[ 1.        ,  1.        ],
#        [ 1.0010001 ,  0.999999  ],
#        [ 1.0020002 ,  0.99999599],
#        ...,
#        [ 0.7840171 , -0.96010809],
#        [ 0.78305715, -0.95980554],
#        [ 0.78209749, -0.95950217]])

# %%
## Setting up the true system
true_y0 = torch.from_numpy(xTrain[0,:]).to(device).to(dtype=torch.double)
t = torch.from_numpy(tTrain).to(dtype=torch.double)
true_y = torch.from_numpy(xTrIter 0001 | Total Loss 0.972929
Iter 0020 | Total Loss 14.484574
Iter 0040 | Total Loss 112.151211
Iter 0060 | Total Loss 310.542264
Iter 0080 | Total Loss 282.873306
Iter 0100 | Total Loss 325.486315
Iter 0120 | Total Loss 177.057714
Iter 0140 | Total Loss 126.592681
Iter 0160 | Total Loss 132.046390
Iter 0180 | Total Loss 117.078121
Iter 0200 | Total Loss 99.273118
Iter 0220 | Total Loss 84.888952
Iter 0240 | Total Loss 93.089225
Iter 0260 | Total Loss 60.608700
Iter 0280 | Total Loss 57.509082
Iter 0300 | Total Loss 66.075732
Iter 0320 | Total Loss 69.486052
Iter 0340 | Total Loss 54.832768
Iter 0360 | Total Loss 55.080360
Iter 0380 | Total Loss 51.271929
Iter 0400 | Total Loss 47.958440
Iter 0420 | Total Loss 36.ain).unsqueeze(1).to(dtype=torch.double)

# %%
## Get mini-batch data from the training dataset 
def get_batch():
    s = torch.from_numpy(np.random.choice(np.arange(args.data_size - args.batch_time, dtype=np.int64), args.batch_size, replace=False))
    batch_y0 = true_y[s]  # (M, D)
    batch_t = torch.stack([t[i:i+args.batch_time] for i in s]) # (T)
    batch_y_dummy = torch.stack([true_y[s + i] for i in range(args.batch_time)], dim=2)  # (T, M, D)
    temp= batch_y_dummy.squeeze(dim=1)
    batch_y=temp.unsqueeze(0)
    #batch_y=batch_y.permute(2,0,1,3)
    return batch_y0.to(device), batch_t.to(device), batch_y.to(device)

# %%
# Construct a neural network to approximate the dynamics of an ODE
class ODEFunc(nn.Module):

    def __init__(self):
        super(ODEFunc, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(2, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 16),
            nn.ReLU(),
            nn.Linear(16, 2)
        ).to(torch.float64)

        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)

    def forward(self, t, y):
        return self.net(y)
    
func = ODEFunc().to(device)

# %%
solutions = []
temp1 = 0
for ic in batch_y0:
    sol = odeint(func, ic[0], batch_t[temp1])
    solutions.append(sol)
    temp1 = temp1+1
pred_toCalcLoss= torch.stack(solutions).unsqueeze(0)

# %%
pred_toCalcLoss-batch_y
# Out:
# tensor([[[[ 0.0000e+00,  0.0000e+00],
#           [-6.0062e-05,  2.2269e-03],
#           [-1.1793e-04,  4.4540e-03],
#           [-1.7362e-04,  6.6815e-03],
#           [-2.2711e-04,  8.9091e-03],
#           [-2.7840e-04,  1.1137e-02],
#           [-3.2751e-04,  1.3365e-02],
#           [-3.7443e-04,  1.5594e-02],
#           [-4.1916e-04,  1.7822e-02],
#           [-4.6169e-04,  2.0051e-02],
#           [-5.0204e-04,  2.2280e-02],
#           [-5.4019e-04,  2.4508e-02],
#           [-5.7615e-04,  2.6738e-02],
#           [-6.0992e-04,  2.8967e-02],
#           [-6.4150e-04,  3.1196e-02]],
#
#          [[ 0.0000e+00,  0.0000e+00],
#           [-2.3797e-04,  2.1371e-03],
#           [-4.7379e-04,  4.2762e-03],
#           [-7.0746e-04,  6.4172e-03],
#           [-9.3899e-04,  8.5601e-03],
#           [-1.1684e-03,  1.0705e-02],
#           [-1.3956e-03,  1.2851e-02],
#           [-1.6207e-03,  1.5000e-02],
#           [-1.8436e-03,  1.7150e-02],
#           [-2.0644e-03,  1.9302e-02],
#           [-2.2830e-03,  2.1456e-02],
#           [-2.4995e-03,  2.3611e-02],
#           [-2.7138e-03,  2.5769e-02],
#           [-2.9260e-03,  2.7927e-02],
#           [-3.1360e-03,  3.0088e-02]],
#
#          [[ 0.0000e+00,  0.0000e+00],
#           [-1.7981e-04,  2.1818e-03],
#           [-3.5746e-04,  4.3650e-03],
#           [-2.8773e-03,  2.3273e-02],
#           [-3.1259e-03,  2.5400e-02],
#           [-3.3724e-03,  2.7529e-02],
#           [-3.6168e-03,  2.9660e-02]],
#
#          [[ 0.0000e+00,  0.0000e+00],
#           [-8.3272e-04,  1.0427e-03],
#           [-1.6644e-03,  2.0889e-03],
#           [-2.4950e-03,  3.1387e-03],
#           [-3.3245e-03,  4.1921e-03],
#           [-4.1530e-03,  5.2490e-03],
#           [-4.9803e-03,  6.3094e-03],
#           [-5.8066e-03,  7.3734e-03],
#           [-6.6319e-03,  8.4410e-03],
#           [-7.4560e-03,  9.5121e-03],
#           [-8.2790e-03,  1.0587e-02],
#           [-9.1010e-03,  1.1665e-02],
#           [-9.9218e-03,  1.2747e-02],
#           [-1.0742e-02,  1.3832e-02],
#           [-1.1560e-02,  1.4921e-02]],
#
#          [[ 0.0000e+00,  0.0000e+00],
#           [-2.2878e-05,  2.2293e-03],
#           [-4.3564e-05,  4.4585e-03],
#           [-6.2060e-05,  6.6877e-03],
#           [-7.8365e-05,  8.9169e-03],
#           [-9.2478e-05,  1.1146e-02],
#           [-1.0440e-04,  1.3375e-02],
#           [-1.1413e-04,  1.5604e-02],
#           [-1.2168e-04,  1.7833e-02],
#           [-1.2703e-04,  2.0061e-02],
#           [-1.3019e-04,  2.2290e-02],
#           [-1.3116e-04,  2.4518e-02],
#           [-1.2994e-04,  2.6746e-02],
#           [-1.2653e-04,  2.8974e-02],
#           [-1.2093e-04,  3.1202e-02]],
#
#          [[ 0.0000e+00,  0.0000e+00],
#           [-9.8703e-04,  2.7729e-04],
#           [-1.9738e-03,  5.5722e-04],
#           [-2.9604e-03,  8.3980e-04],
#           [-3.9467e-03,  1.1250e-03],
#           [-4.9328e-03,  1.4129e-03],
#           [-5.9186e-03,  1.7035e-03],
#           [-6.9042e-03,  1.9967e-03],
#           [-7.8896e-03,  2.2926e-03],
#           [-8.8746e-03,  2.5912e-03],
#           [-9.8595e-03,  2.8925e-03],
#           [-1.0844e-02,  3.1965e-03],
#           [-1.1828e-02,  3.5032e-03],
#           [-1.2812e-02,  3.8127e-03],
#           [-1.3796e-02,  4.1248e-03]]]], dtype=torch.float64,
#        grad_fn=<SubBackward0>)

# %%
ii = 0
## Setting up the optimizer

# Setting up the optimizer with all parameters
optimizer = optim.RMSprop(func.parameters(), lr=0.0001)

for itr in range(1, 4000):
#for itr in range(1, 20):
        ## Using mini-batch data to update the neural network coefficients
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch()
        solutions = []
        temp1 = 0
        for ic in batch_y0:
            sol = odeint(func, ic[0], batch_t[temp1])
            solutions.append(sol)
            temp1 = temp1+1
        pred_toCalcLoss= torch.stack(solutions).unsqueeze(0)
        actual_toCalcLoss = batch_y
        #pred_y = pred_y.permute(2, 1, 0, 3)
        loss = torch.mean(torch.abs(pred_toCalcLoss - actual_toCalcLoss))
        loss.backward()
        optimizer.step()

        if itr % args.test_freq == 0 or itr == 1:
            with torch.no_grad():
                pred_y = odeint(func, true_y0, t)
                pred_toDisplay = pred_y.unsqueeze(1)
                actual_toDisplay = true_y
                loss = torch.mean(torch.abs(pred_toDisplay - actual_toDisplay))
                print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))
                ii += 1
# Out:
# Iter 0001 | Total Loss 14.287166
# Iter 0020 | Total Loss 15.102131
# Iter 0040 | Total Loss 14.736042
# Iter 0060 | Total Loss 14.721254
# Iter 0080 | Total Loss 14.535180
# Iter 0100 | Total Loss 14.288230
# Iter 0120 | Total Loss 14.216921
# Iter 0140 | Total Loss 14.344719
# Iter 0160 | Total Loss 14.108289
# Iter 0180 | Total Loss 14.162457
# Iter 0200 | Total Loss 13.948228
# Iter 0220 | Total Loss 14.158891
# Iter 0240 | Total Loss 13.830265
# Iter 0260 | Total Loss 13.844894
# Iter 0280 | Total Loss 13.817528
# Iter 0300 | Total Loss 13.583471
# Iter 0320 | Total Loss 13.627985
# Iter 0340 | Total Loss 13.626043
# Iter 0360 | Total Loss 13.328907
# Iter 0380 | Total Loss 13.209012
# Iter 0400 | Total Loss 13.408782
# Iter 0420 | Total Loss 13.308576
# Iter 0440 | Total Loss 13.401294
# Iter 0460 | Total Loss 13.292867
# Iter 0480 | Total Loss 13.355492
# Iter 0500 | Total Loss 13.130878
# Iter 0520 | Total Loss 13.245774
# Iter 0540 | Total Loss 13.059004
# Iter 0560 | Total Loss 12.942940
# Iter 0580 | Total Loss 13.022424
# Iter 0600 | Total Loss 13.036813
# Iter 0620 | Total Loss 13.070414
# Iter 0640 | Total Loss 12.963583
# Iter 0660 | Total Loss 12.745968
# Iter 0680 | Total Loss 12.792323
# Iter 0700 | Total Loss 12.575384
# Iter 0720 | Total Loss 12.625862
# Iter 0740 | Total Loss 12.557954
# Iter 0760 | Total Loss 12.602247
# Iter 0780 | Total Loss 12.541353
# Iter 0800 | Total Loss 12.599763
# Iter 0820 | Total Loss 12.585016
# Iter 0840 | Total Loss 12.716836
# Iter 0860 | Total Loss 12.497449
# Iter 0880 | Total Loss 12.564691
# Iter 0900 | Total Loss 12.403981
# Iter 0920 | Total Loss 12.513226
# Iter 0940 | Total Loss 12.272503
# Iter 0960 | Total Loss 12.432419
# Iter 0980 | Total Loss 12.437254
# Iter 1000 | Total Loss 12.235027
# Iter 1020 | Total Loss 12.258257
# Iter 1040 | Total Loss 12.327264
# Iter 1060 | Total Loss 12.117270
# Iter 1080 | Total Loss 12.184734
# Iter 1100 | Total Loss 12.198694
# Iter 1120 | Total Loss 11.922757
# Iter 1140 | Total Loss 12.190003
# Iter 1160 | Total Loss 12.040787
# Iter 1180 | Total Loss 11.980773
# Iter 1200 | Total Loss 12.082574
# Iter 1220 | Total Loss 11.974233
# Iter 1240 | Total Loss 12.155571
# Iter 1260 | Total Loss 11.876619
# Iter 1280 | Total Loss 12.075013
# Iter 1300 | Total Loss 11.995940
# Iter 1320 | Total Loss 11.874575
# Iter 1340 | Total Loss 11.986753
# Iter 1360 | Total Loss 11.935217
# Iter 1380 | Total Loss 11.798695
# Iter 1400 | Total Loss 12.090380
# Iter 1420 | Total Loss 11.845488
# Iter 1440 | Total Loss 11.694983
# Iter 1460 | Total Loss 11.929412
# Iter 1480 | Total Loss 11.727059
# Iter 1500 | Total Loss 11.693966
# Iter 1520 | Total Loss 11.806302
# Iter 1540 | Total Loss 11.808668
# Iter 1560 | Total Loss 11.650375
# Iter 1580 | Total Loss 11.804817
# Iter 1600 | Total Loss 11.732027
# Iter 1620 | Total Loss 11.665784
# Iter 1640 | Total Loss 11.689165
# Iter 1660 | Total Loss 11.660690
# Iter 1680 | Total Loss 11.585300
# Iter 1700 | Total Loss 11.557234
# Iter 1720 | Total Loss 11.702311
# Iter 1740 | Total Loss 11.615444
# Iter 1760 | Total Loss 11.505084
# Iter 1780 | Total Loss 11.522362
# Iter 1800 | Total Loss 11.603359
# Iter 1820 | Total Loss 11.562283
# Iter 1840 | Total Loss 11.473349
# Iter 1860 | Total Loss 11.355051
# Iter 1880 | Total Loss 11.667133
# Iter 1900 | Total Loss 11.446988
# Iter 1920 | Total Loss 11.476028
# Iter 1940 | Total Loss 11.317862
# Iter 1960 | Total Loss 11.321344
# Iter 1980 | Total Loss 11.466443
# Iter 2000 | Total Loss 11.387622
# Iter 2020 | Total Loss 11.427374
# Iter 2040 | Total Loss 11.158225
# Iter 2060 | Total Loss 11.261707
# Iter 2080 | Total Loss 11.510724
# Iter 2100 | Total Loss 11.140868
# Iter 2120 | Total Loss 11.258152
# Iter 2140 | Total Loss 11.327478
# Iter 2160 | Total Loss 11.141705
# Iter 2180 | Total Loss 11.197402
# Iter 2200 | Total Loss 11.301654
# Iter 2220 | Total Loss 11.285454
# Iter 2240 | Total Loss 11.297592
# Iter 2260 | Total Loss 11.213452
# Iter 2280 | Total Loss 11.375536
# Iter 2300 | Total Loss 11.246374
# Iter 2320 | Total Loss 11.276862
# Iter 2340 | Total Loss 11.015372
# Iter 2360 | Total Loss 11.296420
# Iter 2380 | Total Loss 11.259811
# Iter 2400 | Total Loss 11.283799
# Iter 2420 | Total Loss 11.268558
# Iter 2440 | Total Loss 11.271276
# Iter 2460 | Total Loss 10.989202
# Iter 2480 | Total Loss 11.137020
# Iter 2500 | Total Loss 11.132397
# Iter 2520 | Total Loss 11.208636
# Iter 2540 | Total Loss 11.221426
# Iter 2560 | Total Loss 11.220871
# Iter 2580 | Total Loss 11.187045
# Iter 2600 | Total Loss 11.071832
# Iter 2620 | Total Loss 11.164890
# Iter 2640 | Total Loss 11.147783
# Iter 2660 | Total Loss 11.073599
# Iter 2680 | Total Loss 11.107381
# Iter 2700 | Total Loss 10.940124
# Iter 2720 | Total Loss 11.173012
# Iter 2740 | Total Loss 11.071841
# Iter 2760 | Total Loss 11.098144
# Iter 2780 | Total Loss 11.228995
# Iter 2800 | Total Loss 11.089924
# Iter 2820 | Total Loss 11.041023
# Iter 2840 | Total Loss 11.094870
# Iter 2860 | Total Loss 10.988341
# Iter 2880 | Total Loss 10.985527
# Iter 2900 | Total Loss 11.099792
# Iter 2920 | Total Loss 11.072419
# Iter 2940 | Total Loss 10.983150
# Iter 2960 | Total Loss 11.108624
# Iter 2980 | Total Loss 10.944131
# Iter 3000 | Total Loss 11.128350
# Iter 3020 | Total Loss 11.136395
# Iter 3040 | Total Loss 10.979114
# Iter 3060 | Total Loss 11.036420
# Iter 3080 | Total Loss 11.105222
# Iter 3100 | Total Loss 11.075038
# Iter 3120 | Total Loss 10.990384
# Iter 3140 | Total Loss 10.999529
# Iter 3160 | Total Loss 11.040873
# Iter 3180 | Total Loss 11.061980
# Iter 3200 | Total Loss 10.955642
# Iter 3220 | Total Loss 10.974500
# Iter 3240 | Total Loss 10.900765
# Iter 3260 | Total Loss 11.039742
# Iter 3280 | Total Loss 11.072492
# Iter 3300 | Total Loss 10.917055
# Iter 3320 | Total Loss 10.962781
# Iter 3340 | Total Loss 10.909531
# Iter 3360 | Total Loss 10.910808
# Iter 3380 | Total Loss 10.989513
# Iter 3400 | Total Loss 10.852082
# Iter 3420 | Total Loss 10.842300
# Iter 3440 | Total Loss 10.709905
# Iter 3460 | Total Loss 10.895167
# Iter 3480 | Total Loss 10.971191
# Iter 3500 | Total Loss 10.879096
# Iter 3520 | Total Loss 10.766452
# Iter 3540 | Total Loss 10.915592
# Iter 3560 | Total Loss 10.715109
# Iter 3580 | Total Loss 10.863424
# Iter 3600 | Total Loss 10.645888
# Iter 3620 | Total Loss 10.986833
# Iter 3640 | Total Loss 10.743423
# Iter 3660 | Total Loss 10.600896
# Iter 3680 | Total Loss 10.782007
# Iter 3700 | Total Loss 10.805304
# Iter 3720 | Total Loss 10.612507
# Iter 3740 | Total Loss 10.789510
# Iter 3760 | Total Loss 10.835594
# Iter 3780 | Total Loss 10.635856
# Iter 3800 | Total Loss 10.737494
# Iter 3820 | Total Loss 10.688586
# Iter 3840 | Total Loss 10.721606
# Iter 3860 | Total Loss 10.612139
# Iter 3880 | Total Loss 10.696725
# Iter 3900 | Total Loss 10.827335
# Iter 3920 | Total Loss 10.615388
# Iter 3940 | Total Loss 10.814654
# Iter 3960 | Total Loss 10.683766
# Iter 3980 | Total Loss 10.561692

# %%
model = func
#modelVar = funcVariance
# modelSkw = funcSkewness
# modelKurt = funcKurtosis


model.eval()
# modelVar.eval()
# modelSkw.eval()
# modelKurt.eval()


# Initial state
y0 = true_y0
#y0= torch.tensor([ 0,  0.5, 0, 0])

# Time point for prediction
t_value = t
with torch.no_grad():
    reconstruction = odeint(func,y0 , t).to(device)

y0_prediction = reconstruction[-1,:]
tCheck = np.linspace(to,to+1,1000)
xCheckdummy = solution.sol(tCheck)
xCheck = np.transpose(xCheckdummy)

tCheck_nn = torch.from_numpy(tCheck).to(dtype=torch.double)
with torch.no_grad():
    predicted_states = odeint(func,y0_prediction , tCheck_nn).to(device)

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.plot(xTrain[:,0],xTrain[:,1], 'b',label='Ground truth training')
plt.plot(reconstruction[:,0],reconstruction[:,1], 'b--',label='NODE')
plt.plot(xCheck[:,0],xCheck[:,1], 'r',label='Ground truth future')
plt.plot(predicted_states[:,0],predicted_states[:,1], 'g-',label='NODE Prediction')


ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

# Customize fonts and sizes
ax.set_title("Learning evolution of Mean, Var, Skw, Kurt", fontsize=18, fontweight='bold')
ax.set_xlabel("X-axis", fontsize=14, fontweight='bold')
ax.set_ylabel("Y-axis", fontsize=14, fontweight='bold')

# Increase tick label font size
ax.tick_params(axis='both', labelsize=12)

# Customize the appearance of the legend
legend = ax.legend(loc='lower right', fontsize=12)
legend.get_frame().set_edgecolor('black')
ax.set_facecolor('#F4F4F4')

#plt.savefig('plot3_Mean_all_parts.pdf', bbox_inches='tight')

# Show the plot
plt.show()
